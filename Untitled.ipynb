# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
import numpy as np
from sklearn.model_selection import train_test_split
import sklearn.metrics
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report,confusion_matrix

# %%
data = pd.read_table('data/olympics.csv', sep=',', header=0, engine='python')

# %%
data = data.replace({'Sex' : { 'F' : 0, 'M' : 1}})
data = data.replace({'Season' : { 'Summer' : 0, 'Winter' : 1}})

# %%
temp = data.pop('Medal')
data['Medal']=temp

# %%
data.head()
# Out:
#                              Name  Sex   Age  Height  Weight Country  Year  \
# 0                  Leszek Hensler    1  24.0   172.0    70.0  Poland  1980
# 1             Stanisaw Wierzbicki    1  21.0   189.0    87.0  Poland  1980
# 2      Jacek Maria Wierzchowiecki    1  36.0   170.0    68.0  Poland  1980
# 3  Barbara Bronisawa Baran-Wojnar    0  20.0   168.0    55.0  Poland  1980
# 4                  Wadysaw Stecyk    1  29.0   156.0    52.0  Poland  1980
#
#    Season          Sport                                            Event  \
# 0       0         Hockey                              Hockey Men's Hockey
# 1       0         Rowing                    Rowing Men's Quadruple Sculls
# 2       0  Equestrianism  Equestrianism Mixed Three-Day Event, Individual
# 3       0      Athletics                      Athletics Women's Long Jump
# 4       0      Wrestling             Wrestling Men's Flyweight, Freestyle
#
#    Average Temperature  GDP Per Capita  Medal
# 0                 7.85    17091.859905    0.0
# 1                 7.85    17091.859905    0.0
# 2                 7.85    17091.859905    0.0
# 3                 7.85    17091.859905    0.0
# 4                 7.85    17091.859905    2.0

# %%
sports = data['Sport'].unique()

# %%
sport_label = dict(zip(sports, range(len(sports))))

# %%
data['Sport'] = [sport_label[s] for s in data['Sport']]

# %%
# Out:
# {'Hockey': 0,
#  'Rowing': 1,
#  'Equestrianism': 2,
#  'Athletics': 3,
#  'Wrestling': 4,
#  'Handball': 5,
#  'Nordic Combined': 6,
#  'Swimming': 7,
#  'Boxing': 8,
#  'Weightlifting': 9,
#  'Volleyball': 10,
#  'Canoeing': 11,
#  'Modern Pentathlon': 12,
#  'Gymnastics': 13,
#  'Shooting': 14,
#  'Ice Hockey': 15,
#  'Fencing': 16,
#  'Basketball': 17,
#  'Cycling': 18,
#  'Sailing': 19,
#  'Diving': 20,
#  'Speed Skating': 21,
#  'Archery': 22,
#  'Judo': 23,
#  'Ski Jumping': 24,
#  'Cross Country Skiing': 25,
#  'Alpine Skiing': 26,
#  'Figure Skating': 27,
#  'Rhythmic Gymnastics': 28,
#  'Table Tennis': 29,
#  'Tennis': 30,
#  'Football': 31,
#  'Biathlon': 32,
#  'Luge': 33,
#  'Badminton': 34,
#  'Short Track Speed Skating': 35,
#  'Bobsleigh': 36,
#  'Snowboarding': 37,
#  'Taekwondo': 38,
#  'Skeleton': 39,
#  'Triathlon': 40,
#  'Freestyle Skiing': 41,
#  'Beach Volleyball': 42,
#  'Water Polo': 43,
#  'Synchronized Swimming': 44,
#  'Baseball': 45,
#  'Softball': 46,
#  'Trampolining': 47,
#  'Curling': 48,
#  'Golf': 49,
#  'Rugby Sevens': 50}

# %%
data
# Out:
#                                     Name  Sex   Age  Height  Weight  \
# 0                         Leszek Hensler    1  24.0   172.0    70.0
# 1                    Stanisaw Wierzbicki    1  21.0   189.0    87.0
# 2             Jacek Maria Wierzchowiecki    1  36.0   170.0    68.0
# 3         Barbara Bronisawa Baran-Wojnar    0  20.0   168.0    55.0
# 4                         Wadysaw Stecyk    1  29.0   156.0    52.0
# 5             Jacek Maria Wierzchowiecki    1  36.0   170.0    68.0
# 6                   Alfred Jzef Kauziski    1  27.0   190.0    81.0
# 7                Stanisaw Hubert Kawulok    1  26.0   171.0    68.0
# 8                       Leszek Jan Grski    1  18.0   184.0    85.0
# 9                      Zygmunt Gosiewski    1  20.0   182.0    71.0
# 10                         Ryszard Burak    1  26.0   185.0    92.0
# 11                        Adam Starostka    1  23.0   180.0    79.0
# 12                     Tadeusz Demboczyk    1  24.0   155.0    56.0
# 13                             Lech asko    1  24.0   197.0    88.0
# 14                             Marek bik    1  22.0   180.0    80.0
# 15       Grayna Oliszewska (-Baumgarten)    0  20.0   161.0    58.0
# 16                             Marek bik    1  22.0   180.0    80.0
# 17       Grayna Oliszewska (-Baumgarten)    0  20.0   161.0    58.0
# 18                          Jan Olesiski    1  23.0   186.0    72.0
# 19                          Jan Olesiski    1  23.0   186.0    72.0
# 20                 Grzegorz Jzef Stellak    1  29.0   197.0    95.0
# 21                 Grzegorz Jzef Stellak    1  29.0   197.0    95.0
# 22                    Krzysztof Potaczek    1  22.0   176.0    66.0
# 23                        Andrzej Mikina    1  24.0   188.0    90.0
# 24                          Tomasz Busse    1  23.0   188.0    92.0
# 25              Krzysztof Jzef Stefaniak    1  22.0   182.0    66.0
# 26                    Jerzy Andrzej Potz    1  27.0   180.0    85.0
# 27              Danuta Bukowska (-Milej)    0  21.0   178.0    57.0
# 28                 Bohdan Adam Buakowski    1  30.0   181.0    67.0
# 29                 Bohdan Adam Buakowski    1  30.0   181.0    67.0
# ...                                  ...  ...   ...     ...     ...
# 130294                           Saa Mii    1  29.0   198.0   109.0
# 130295                    Sran Mrvaljevi    1  32.0   186.0    85.0
# 130296                      Ema Ramusovi    0  19.0   183.0    78.0
# 130297                 Aleksandar Radovi    1  29.0   191.0    98.0
# 130298                      Zdravko Radi    1  37.0   193.0    96.0
# 130299            Jovanka "Jova" Radievi    0  29.0   170.0    68.0
# 130300          Bojana Popovi (Petrovi-)    0  36.0   188.0    86.0
# 130301                Marina Vukevi-Raji    0  22.0   175.0    70.0
# 130302                      Danka Kovini    0  21.0   169.0    67.0
# 130303                    Drako Brguljan    1  31.0   194.0    92.0
# 130304                    Darko Brguljan    1  25.0   180.0    97.0
# 130305                 Katarina Bulatovi    0  31.0   186.0    71.0
# 130306                    Anela Bulatovi    0  29.0   175.0    67.0
# 130307                       Logona Esau    1  21.0   163.0    69.0
# 130308                  Tuau Lapua Lapua    1  21.0   140.0    62.0
# 130309                      Tavevele Noa    1  20.0   176.0    74.0
# 130310                   Etimoni Timuani    1  24.0   184.0    72.0
# 130311                        Anju Jason    1  20.0   178.0    80.0
# 130312                 Julianne Kirchner    0  16.0   138.0    54.0
# 130313                Haley Nicole Nemra    0  18.0   168.0    59.0
# 130314                    Jared J. Heine    1  23.0   179.0    70.0
# 130315               Timi Hilly Garstang    1  25.0   175.0    73.0
# 130316                    Giordan Harris    1  19.0   185.0    99.0
# 130317          Ann-Marie "Annie" Hepler    0  16.0   167.0    68.0
# 130318                Haley Nicole Nemra    0  22.0   168.0    59.0
# 130319                  Colleen Furgeson    0  17.0   176.0    65.0
# 130320  Mathlynn Langtor "Mattie" Sasser    0  19.0   158.0    58.0
# 130321                     Mariana Cress    0  17.0   159.0    52.0
# 130322                    Richson Simeon    1  18.0   155.0    78.0
# 130323                    Giordan Harris    1  23.0   185.0    99.0
#
#                  Country  Year  Season  Sport  \
# 0                 Poland  1980       0      0
# 1                 Poland  1980       0      1
# 2                 Poland  1980       0      2
# 3                 Poland  1980       0      3
# 4                 Poland  1980       0      4
# 5                 Poland  1980       0      2
# 6                 Poland  1980       0      5
# 7                 Poland  1980       1      6
# 8                 Poland  1980       0      7
# 9                 Poland  1980       0      8
# 10                Poland  1980       0      1
# 11                Poland  1980       0      3
# 12                Poland  1980       0      9
# 13                Poland  1980       0     10
# 14                Poland  1980       0     11
# 15                Poland  1980       0      3
# 16                Poland  1980       0     11
# 17                Poland  1980       0      3
# 18                Poland  1980       0     12
# 19                Poland  1980       0     12
# 20                Poland  1980       0      1
# 21                Poland  1980       0      1
# 22                Poland  1980       0     13
# 23                Poland  1980       0      0
# 24                Poland  1980       0      4
# 25                Poland  1980       0     14
# 26                Poland  1980       1     15
# 27                Poland  1980       0      3
# 28                Poland  1980       0      3
# 29                Poland  1980       0      3
# ...                  ...   ...     ...    ...
# 130294        Montenegro  2016       0     43
# 130295        Montenegro  2016       0     23
# 130296        Montenegro  2016       0      5
# 130297        Montenegro  2016       0     43
# 130298        Montenegro  2016       0     43
# 130299        Montenegro  2016       0      5
# 130300        Montenegro  2016       0      5
# 130301        Montenegro  2016       0      5
# 130302        Montenegro  2016       0     30
# 130303        Montenegro  2016       0     43
# 130304        Montenegro  2016       0     43
# 130305        Montenegro  2016       0      5
# 130306        Montenegro  2016       0      5
# 130307            Tuvalu  2008       0      9
# 130308            Tuvalu  2012       0      9
# 130309            Tuvalu  2012       0      3
# 130310            Tuvalu  2016       0      3
# 130311  Marshall Islands  2008       0     38
# 130312  Marshall Islands  2008       0      7
# 130313  Marshall Islands  2008       0      3
# 130314  Marshall Islands  2008       0      7
# 130315  Marshall Islands  2012       0      3
# 130316  Marshall Islands  2012       0      7
# 130317  Marshall Islands  2012       0      7
# 130318  Marshall Islands  2012       0      3
# 130319  Marshall Islands  2016       0      7
# 130320  Marshall Islands  2016       0      9
# 130321  Marshall Islands  2016       0      3
# 130322  Marshall Islands  2016       0      3
# 130323  Marshall Islands  2016       0      7
#
#                                                     Event  \
# 0                                     Hockey Men's Hockey
# 1                           Rowing Men's Quadruple Sculls
# 2         Equestrianism Mixed Three-Day Event, Individual
# 3                             Athletics Women's Long Jump
# 4                    Wrestling Men's Flyweight, Freestyle
# 5               Equestrianism Mixed Three-Day Event, Team
# 6                                 Handball Men's Handball
# 7                        Nordic Combined Men's Individual
# 8             Swimming Men's 400 metres Individual Medley
# 9                         Boxing Men's Light-Middleweight
# 10                          Rowing Men's Quadruple Sculls
# 11                   Athletics Men's 4 x 400 metres Relay
# 12                       Weightlifting Men's Bantamweight
# 13                            Volleyball Men's Volleyball
# 14            Canoeing Men's Canadian Singles, 500 metres
# 15                 Athletics Women's 4 x 400 metres Relay
# 16          Canoeing Men's Canadian Singles, 1,000 metres
# 17                           Athletics Women's 400 metres
# 18                           Modern Pentathlon Men's Team
# 19                     Modern Pentathlon Men's Individual
# 20                               Rowing Men's Coxed Fours
# 21                              Rowing Men's Coxed Eights
# 22                       Gymnastics Men's Pommelled Horse
# 23                                    Hockey Men's Hockey
# 24                 Wrestling Men's Heavyweight, Freestyle
# 25      Shooting Mixed Small-Bore Rifle, Prone, 50 metres
# 26                            Ice Hockey Men's Ice Hockey
# 27                            Athletics Women's High Jump
# 28                     Athletics Men's 50 kilometres Walk
# 29                     Athletics Men's 20 kilometres Walk
# ...                                                   ...
# 130294                        Water Polo Men's Water Polo
# 130295                       Judo Men's Half-Middleweight
# 130296                          Handball Women's Handball
# 130297                        Water Polo Men's Water Polo
# 130298                        Water Polo Men's Water Polo
# 130299                          Handball Women's Handball
# 130300                          Handball Women's Handball
# 130301                          Handball Women's Handball
# 130302                             Tennis Women's Singles
# 130303                        Water Polo Men's Water Polo
# 130304                        Water Polo Men's Water Polo
# 130305                          Handball Women's Handball
# 130306                          Handball Women's Handball
# 130307                    Weightlifting Men's Lightweight
# 130308                  Weightlifting Men's Featherweight
# 130309                         Athletics Men's 100 metres
# 130310                         Athletics Men's 100 metres
# 130311                       Taekwondo Men's Welterweight
# 130312               Swimming Women's 50 metres Freestyle
# 130313                       Athletics Women's 800 metres
# 130314               Swimming Men's 100 metres Backstroke
# 130315                         Athletics Men's 100 metres
# 130316                 Swimming Men's 50 metres Freestyle
# 130317               Swimming Women's 50 metres Freestyle
# 130318                       Athletics Women's 800 metres
# 130319               Swimming Women's 50 metres Freestyle
# 130320                  Weightlifting Women's Lightweight
# 130321                       Athletics Women's 100 metres
# 130322                         Athletics Men's 100 metres
# 130323                 Swimming Men's 50 metres Freestyle
#
#         Average Temperature  GDP Per Capita  Medal
# 0                      7.85    17091.859905    0.0
# 1                      7.85    17091.859905    0.0
# 2                      7.85    17091.859905    0.0
# 3                      7.85    17091.859905    0.0
# 4                      7.85    17091.859905    2.0
# 5                      7.85    17091.859905    0.0
# 6                      7.85    17091.859905    0.0
# 7                      7.85    17091.859905    0.0
# 8                      7.85    17091.859905    0.0
# 9                      7.85    17091.859905    0.0
# 10                     7.85    17091.859905    0.0
# 11                     7.85    17091.859905    0.0
# 12                     7.85    17091.859905    3.0
# 13                     7.85    17091.859905    0.0
# 14                     7.85    17091.859905    0.0
# 15                     7.85    17091.859905    0.0
# 16                     7.85    17091.859905    0.0
# 17                     7.85    17091.859905    0.0
# 18                     7.85    17091.859905    0.0
# 19                     7.85    17091.859905    0.0
# 20                     7.85    17091.859905    3.0
# 21                     7.85    17091.859905    0.0
# 22                     7.85    17091.859905    0.0
# 23                     7.85    17091.859905    0.0
# 24                     7.85    17091.859905    0.0
# 25                     7.85    17091.859905    0.0
# 26                     7.85    17091.859905    0.0
# 27                     7.85    17091.859905    0.0
# 28                     7.85    17091.859905    0.0
# 29                     7.85    17091.859905    0.0
# ...                     ...             ...    ...
# 130294                10.55     9314.297972    0.0
# 130295                10.55     9314.297972    0.0
# 130296                10.55     9314.297972    0.0
# 130297                10.55     9314.297972    0.0
# 130298                10.55     9314.297972    0.0
# 130299                10.55     9314.297972    0.0
# 130300                10.55     9314.297972    0.0
# 130301                10.55     9314.297972    0.0
# 130302                10.55     9314.297972    0.0
# 130303                10.55     9314.297972    0.0
# 130304                10.55     9314.297972    0.0
# 130305                10.55     9314.297972    0.0
# 130306                10.55     9314.297972    0.0
# 130307                28.00     3949.793733    0.0
# 130308                28.00     3949.793733    0.0
# 130309                28.00     3949.793733    0.0
# 130310                28.00     3949.793733    0.0
# 130311                27.40     3965.345511    0.0
# 130312                27.40     3965.345511    0.0
# 130313                27.40     3965.345511    0.0
# 130314                27.40     3965.345511    0.0
# 130315                27.40     3965.345511    0.0
# 130316                27.40     3965.345511    0.0
# 130317                27.40     3965.345511    0.0
# 130318                27.40     3965.345511    0.0
# 130319                27.40     3965.345511    0.0
# 130320                27.40     3965.345511    0.0
# 130321                27.40     3965.345511    0.0
# 130322                27.40     3965.345511    0.0
# 130323                27.40     3965.345511    0.0
#
# [130324 rows x 13 columns]

# %%
scaler = StandardScaler()

# %%
y = data.pop('Medal')

# %%
Y = y.values

# %%
X = data.copy()

# %%
X.pop('Name')
X.pop('Country')
X.pop('Event')
# Out:
# 0                                       Hockey Men's Hockey
# 1                             Rowing Men's Quadruple Sculls
# 2           Equestrianism Mixed Three-Day Event, Individual
# 3                               Athletics Women's Long Jump
# 4                      Wrestling Men's Flyweight, Freestyle
# 5                 Equestrianism Mixed Three-Day Event, Team
# 6                                   Handball Men's Handball
# 7                          Nordic Combined Men's Individual
# 8               Swimming Men's 400 metres Individual Medley
# 9                           Boxing Men's Light-Middleweight
# 10                            Rowing Men's Quadruple Sculls
# 11                     Athletics Men's 4 x 400 metres Relay
# 12                         Weightlifting Men's Bantamweight
# 13                              Volleyball Men's Volleyball
# 14              Canoeing Men's Canadian Singles, 500 metres
# 15                   Athletics Women's 4 x 400 metres Relay
# 16            Canoeing Men's Canadian Singles, 1,000 metres
# 17                             Athletics Women's 400 metres
# 18                             Modern Pentathlon Men's Team
# 19                       Modern Pentathlon Men's Individual
# 20                                 Rowing Men's Coxed Fours
# 21                                Rowing Men's Coxed Eights
# 22                         Gymnastics Men's Pommelled Horse
# 23                                      Hockey Men's Hockey
# 24                   Wrestling Men's Heavyweight, Freestyle
# 25        Shooting Mixed Small-Bore Rifle, Prone, 50 metres
# 26                              Ice Hockey Men's Ice Hockey
# 27                              Athletics Women's High Jump
# 28                       Athletics Men's 50 kilometres Walk
# 29                       Athletics Men's 20 kilometres Walk
#                                 ...
# 130294                          Water Polo Men's Water Polo
# 130295                         Judo Men's Half-Middleweight
# 130296                            Handball Women's Handball
# 130297                          Water Polo Men's Water Polo
# 130298                          Water Polo Men's Water Polo
# 130299                            Handball Women's Handball
# 130300                            Handball Women's Handball
# 130301                            Handball Women's Handball
# 130302                               Tennis Women's Singles
# 130303                          Water Polo Men's Water Polo
# 130304                          Water Polo Men's Water Polo
# 130305                            Handball Women's Handball
# 130306                            Handball Women's Handball
# 130307                      Weightlifting Men's Lightweight
# 130308                    Weightlifting Men's Featherweight
# 130309                           Athletics Men's 100 metres
# 130310                           Athletics Men's 100 metres
# 130311                         Taekwondo Men's Welterweight
# 130312                 Swimming Women's 50 metres Freestyle
# 130313                         Athletics Women's 800 metres
# 130314                 Swimming Men's 100 metres Backstroke
# 130315                           Athletics Men's 100 metres
# 130316                   Swimming Men's 50 metres Freestyle
# 130317                 Swimming Women's 50 metres Freestyle
# 130318                         Athletics Women's 800 metres
# 130319                 Swimming Women's 50 metres Freestyle
# 130320                    Weightlifting Women's Lightweight
# 130321                         Athletics Women's 100 metres
# 130322                           Athletics Men's 100 metres
# 130323                   Swimming Men's 50 metres Freestyle
# Name: Event, Length: 130324, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
scaler.fit(X)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/preprocessing/data.py:617: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   """Entry point for launching an IPython kernel.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.

# %%
mlp = MLPClassifier(hidden_layer_sizes=(200,200), max_iter=500)

# %%
mlp.fit(X_train,y_train)

# %%
predictions = mlp.predict(X_test)

# %%
accuracy = sklearn.metrics.accuracy_score(predictions, y_test)

# %%
accuracy
